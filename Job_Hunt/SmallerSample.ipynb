# %%
from bs4 import BeautifulSoup
from splinter import Browser
import time
import requests
import pandas as pd
from sqlalchemy import create_engine
from config import password

# %%
engine = create_engine(f'postgresql://postgres:{password}@localhost:5432/jobs')

# %%
executable_path = {'executable_path': 'chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=False)

# %%
url = "https://www.builtinchicago.org/jobs"
browser.visit(url)
time.sleep(1)
browser.click_link_by_partial_text('Data')
# Out:
# C:\Users\walsh\anaconda3\lib\site-packages\splinter\driver\webdriver\__init__.py:528: FutureWarning: browser.find_link_by_partial_text is deprecated. Use browser.links.find_by_partial_text instead.
#   FutureWarning,

# %%
#Create lists to hold data to put into columns for a dataframe
Job_Title = []
Company = []
City = []
Field = []
Tech_Hub = []
#loop of Tech Hubs, but changed to 5 because the hubs of sf and seattle don't have the same page structure.
city_loop = ["chicago","boston","austin","colorado","nyc","la"]
#List of job fields that I wish to click through as I loop through the different Tech Hubs
Fields = ["Dev + Engineer","Design + UX","Product","Marketing","Finance","Sales","Data + Analytics"]

#loop to go through the different tech hubs
for c in city_loop:
    #logic adapt urls based on the tech hub desired. logic to handle the fact that chicago was .org and the rest were .com
    if c in ["chicago"]:
        url =f"https://www.builtin{c}.org/jobs"
    else: 
        url =f"https://www.builtin{c}.com/jobs"
    # browse to the tech hub url
    browser.visit(url)
    # slight delay to let the page load
    time.sleep(1)
    #loop to go through and click the different job field options
    for field in Fields:
        
        #How I found out sf and seattle didn't function
        #click field buttons
        browser.click_link_by_partial_text(field)
        print(field)
        #pause to let the page load
        time.sleep(2)
        
        #grab the html code of the page
        html = browser.html
        #read and store html as a soup object
        soup = BeautifulSoup(html, 'html.parser')
        #grab all subsections of "left-col" which are the containers with the job postings and store in a list
        comp_jobs = soup.find_all('div', class_="left-col")
        k=0
        #Loop through the subsections and do so as integers so that list items can be referenced
        while k < 5:
            try:
                #store title, company, and city
                title = comp_jobs[k].find('h2',class_="title").text
                company=comp_jobs[k].find('div',class_="company-title").text
                print(f"{title},{company}")
                Field.append(field)
                Job_Title.append(title)
                Company.append(company)
                Tech_Hub.append(c)
                try:
                    city=comp_jobs[k].find('div',class_="job-location").text
                    City.append(city)
                except:
                    City.append("None")
                k+=1
            except:
                pass
        time.sleep(0.5)
        browser.click_link_by_partial_text(field)
        time.sleep(1)
# Out:
# C:\Users\walsh\anaconda3\lib\site-packages\splinter\driver\webdriver\__init__.py:528: FutureWarning: browser.find_link_by_partial_text is deprecated. Use browser.links.find_by_partial_text instead.
#   FutureWarning,
# Dev + Engineer
# Senior Software Engineer, Front End,Kalderos
# Senior Site Reliability Engineer,Optiver
# Cloud Engineer,Slalom
# Sr. Microsoft Cloud Engineer,DFIN
# Senior Site Reliability Engineer, Observability,Cisco Meraki
# Design + UX
# Product Designer,Flare Health
# Product Design Manager,HealthJoy
# Senior Product Designer, Business Development,Root Insurance
# Design Lead - Credit Products,Morningstar
# Lead Product Designer,Kalderos
# Product
# Product Designer,Flare Health
# Product Design Manager,HealthJoy
# Senior Product Designer, Business Development,Root Insurance
# Design Lead - Credit Products,Morningstar
# Lead Product Designer,Kalderos
# Marketing
# Campaign Specialist,Tribune Publishing
# Social Media Strategist,Codal
# Demand Generation Manager,Hologram, Inc.
# Email Marketing Specialist,Club Automation
# Copywriter,Club Automation
# Finance
# Senior Financial Analyst,Packback
# Head of Finance,Hologram, Inc.
# FP&A Manager,Clearcover
# Director of Finance,Belvedere Trading
# Assistant Controller,GoHealth
# Sales
# Account Executive,Litera Microsystems
# Sales Representative - Fintech Software Sales,Palette Software
# Sales Manager,Spark Hire
# Business Development Executive,Syndigo
# Sales Development Representative,BRD
# Data + Analytics
# Data Architect,3Cloud
# Business Intelligence Manager,Kalderos
# Applied Data Science Lead, Government,Civis Analytics
# Senior DB2 iSeries Database Administrator,OneMain Financial
# Principal Big data solutions architect,Discover
# Dev + Engineer
# Senior Software Engineer, Activation,CircleCI
# Senior Client Success Consultant,Mirakl
# Office Administrator ,XL Fleet
# Regional Merchandising Director,Indigo
# Software Development Manager,Chewy
# Design + UX
# Principal Conversation User Experience Designer,Nuance
# Senior Product Designer,PathAI
# Senior User Experience Designer: Healthcare,Nuance
# Manager, User Experience,Acquia
# Product Experience Designer,Markforged
# Product
# Director of Product Management,CircleCI
# Senior Product Manager,3Play Media
# Product Analyst,Peapod Digital Labs
# Product Designer,Wellframe
# Services Product Manager, Global Markets,Indigo
# Marketing
# Marketing Analytics Guru,Dynatrace
# Growth Marketer - Digital Marketing &,Embark Veterinary
# Marketing Manager,detectify
# Chief Marketing Officer,Mirakl
# Manager, Email Marketing,iZotope
# Finance
# APPLICATIONS ENGINEER - APAC,HPR
# Implementation Technical Lead,Arcadia
# Inside Sales Representative,EverQuote
# Regional Merchandising Director,Indigo
# Software Development Manager,Chewy
# Sales
# Manager, Partnerships America,Scandit
# Enterprise Partner Sales Advisor,Drift
# Account Executive, Corporate Development (Beijing),SS&C Intralinks
# Vice President Regional Sales, Leadership and Busi…,Skillsoft
# Senior Business Development Representative,Mirakl
# Data + Analytics
# Machine Learning Engineer,Kensho Technologies
# Director of People Analytics,Workhuman
# Senior Data Analyst,Vistaprint
# Data Scientist,Klaviyo
# Software Engineer in Big Data Integration,Arcadia
# Dev + Engineer
# Front End Engineer,Volusion
# SOFTWARE QUALITY ASSURANCE ANALYST,Banyan Water
# Senior Production Engineer,WP Engine
# Software Engineer,RapidDeploy
# Associate Software Engineer,RapidDeploy
# Design + UX
# Senior Frontend Developer,Pushnami
# Senior Designer,Atlassian
# Director of Product Design for Partners Segment,GoDaddy
# Product Designer,Cloudflare
# Senior Interaction Designer,DISCO
# Product
# Global Senior Product Manager,Cision (formerly TrendKite)
# Technical Product Manager,ePayPolicy
# VP of Product,Volusion
# Principal Product Manager,realtor.com
# Product Delivery Operations Manager,Bright Health
# Marketing
# Mid-level ASP .NET/MVC Developer ,ePayPolicy
# Mid-Market Account Development Representative-Duo,Duo Security
# Senior Accounts Payable Specialist,FloSports
# Product Designer,Cloudflare
# Software Engineer,RapidDeploy
# Finance
# Accounting Manager (GL),Miro
# Senior Accounting Manager,Juniper Square
# Revenue Operations Manager (Customer Success),Miro
# Senior Accounts Payable Specialist,FloSports
# Accounting Specialist,ScaleFactor
# Sales
# Solutions Architect - Remote,Coder
# Sales Development Program (Austin),Arrive Logistics
# Sales Engineer - West Coast,SpyCloud
# Business Development Representative,Brightpearl
# Strategic Account Executive - Midstream,RigUp
# Data + Analytics
# Principal Database Reliability Engineer,Cognite
# Existing Customer Management Risk Analyst,Self Financial
# Senior Content Data Analyst,A Cloud Guru
# Analyst, Portfolio Management,Amherst
# Big Data Engineer,Cloudflare
# Dev + Engineer
# Electrical Engineer,Outrider
# Senior Software Engineer - Onboarding,Uplight
# Sr Application Security Engineer,Bluprint
# Team Lead, Software Engineering,DAT Solutions
# Software Engineering Manager,DAT Solutions
# Design + UX
# Senior UX/Information Designer-2,IHS Markit Digital
# Creative Director & Lead Designer,DispatchHealth
# Senior Digital Graphic Designer,Automox
# Sr. UX Desginer,DAT Solutions
# Associate WordPress Designer,Zen Planner
# Product
# Product Owner/ Product Manager,Hotel Engine
# Digital Threading Product Manager,IHS Markit Digital
# Technical Product Manager, API Integrations,ReCharge
# Product Owner,Gloo
# Product Manager,LogRhythm
# Marketing
# Technical Marketing Manager - Platform,Sumo Logic
# Field Marketing Manager,Webroot, an OpenText company
# Marketing Campaigns Specialist,BombBomb
# Email Marketing Specialist,Zen Planner
# Integrated Marketing Manager,Healthgrades
# Finance
# Senior Software Systems Engineer,Outrider
# Product Designer,Parsyl
# Sales Associate,Personal Capital
# Team Lead, Software Engineering,DAT Solutions
# Software Engineering Manager,DAT Solutions
# Sales
# Account Manager,NurseFly
# REGIONAL SALES DIRECTOR,Apostrophe, Inc.
# Sr. Sales Operations Analyst,Duda, Inc.
# Solutions Consultant,Snapdocs, Inc.
# Executive Director Sales/Business Development,IHS Markit Digital
# Data + Analytics
# Lead Data Architect,ReCharge
# Data Analyst (Analytics Engineer),Yaguara
# Data Scientist,The Trade Desk
# Business Intelligence Analyst,Evolve Vacation Rental
# Database Administrator - MySQL,Zen Planner
# Dev + Engineer
# Senior Big Data Engineer- Data Warehouse,Integral Ad Science
# iOS Engineer,Zocdoc
# Software Engineer - Generalist,Imagen Technologies
# C++ Developer,MayStreet
# Cloud Engineer,Tipico
# Design + UX
# Full Stack Software Engineer,Zearn
# Leasing Consultant,REZI
# Director of Sales Development,Frame.io
# Customer Support Advisor, Acuity (Remote),Squarespace
# C++ Developer,MayStreet
# Product
# Growth Product Manager,Fluent, Inc.
# Product Manager,VidMob
# Senior Product Manager,Paxos
# Product Manager,Common
# Product Lead - Distributed Commerce,Rokt
# Marketing
# Creative Director, Copy,Ready Set Rocket
# VP of Marketing,Alloy
# Senior Lifecycle Marketing Manager,Teachers Pay Teachers
# Digital Marketing Manager,Tipico
# Director, Product Marketing,BetterCloud
# Finance
# Billing Analyst,Nylas
# Senior Accountant, Brokerage,DriveWealth
# Senior Accountant,Feather
# Manager of Finance and Strategy,Skillshare
# Finance Manager,Tipico
# Sales
# Partnerships Manager,Onna
# Provider Account Manager,Covera Health
# Salesforce Administrator,OwnBackup
# Director of Business Development,Tipico
# Sales Development Representative,Newsela
# Data + Analytics
# Analytics Engineer,LeafLink
# Senior Data Engineer,Zocdoc
# Business Intelligence Analyst, Marketing,Newsela
# Business Intelligence Developer / Analyst,Tipico
# Commissions Analyst,Sisense
# Dev + Engineer
# Computer Vision Scientist,Metropolis
# Sr. Software Engineer,TigerConnect
# DevSecOps / Security Engineer,Cameo
# Propulsion Thermal Structural Analyst,Relativity Space
# Sr. Integration Engineer,Well Health, Inc.
# Design + UX
# Senior Product Designer,Mothership
# Senior UX/UI Designer,Emotive.io
# Sr. Product Designer,CREXi
# UX Design Lead,GoGuardian
# VP, Product Design,Slickdeals
# Product
# Growth Strategy Specialist, Media Partners,TikTok
# Director of Product - Brokerage Platform,Altruist
# Senior Product Manager (Enterprise Insights,Miro
# Head of Global Product Management,iHerb
# Product Manager,SURE
# Marketing
# Facebook Ads Specialist,Golden Hippo
# Ad Review Specialist - LA,TikTok
# Digital Acquisition Marketing Assistant,Golden Hippo
# Manager - Rewards & Membership Program,sweetgreen
# Product Marketing Manager,Honey
# Finance
# Facebook Ads Specialist,Golden Hippo
# Ad Review Specialist - LA,TikTok
# Digital Acquisition Marketing Assistant,Golden Hippo
# Manager - Rewards & Membership Program,sweetgreen
# Product Marketing Manager,Honey
# Sales
# Facebook Ads Specialist,Golden Hippo
# Ad Review Specialist - LA,TikTok
# Digital Acquisition Marketing Assistant,Golden Hippo
# Manager - Rewards & Membership Program,sweetgreen
# Product Marketing Manager,Honey
# Data + Analytics
# Power Electronics Engineer, Inverter,Canoo
# Application Security Architect,GoodRx
# LiveOps Program Manager,Talespin
# Office Manager,Route
# Inside Sales Advisor,byte

# %%
print(len(Field))
print(len(Job_Title))
print(len(Company))
print(len(City))
print(len(Tech_Hub))
# Out:
# 235
# 235
# 235
# 235
# 235

# %%
Fields = ["Dev + Engineer","Design + UX","Product","Marketing","Data + Analytics","Finance"]
sf_loop =["sf","seattle"]
for c in sf_loop:
    if c in ["chicago"]:
        url =f"https://www.builtin{c}.org/jobs"
    else: 
        url =f"https://www.builtin{c}.com/jobs"
#     print(url)
    browser.visit(url)
#     print(c)
    time.sleep(0.25)
    for field in Fields:
        browser.click_link_by_partial_text(field)
        time.sleep(1)
        print(field)
       
        html = browser.html
        #read and store html
        soup = BeautifulSoup(html, 'html.parser')
        comp_jobs = soup.find_all('div', class_="condensed-job-row")
            
        k=0
        #Loop through the subsections and do so as integers so that list items can be referenced
        while k < 5:
            try:
                title = comp_jobs[k].find('h2', class_="job-title").text
                company=comp_jobs[k].find_all('span',class_="param-value")[0].text.strip()
                Field.append(field)
                Job_Title.append(title)
                Company.append(company)
                Tech_Hub.append(c)
                
                try:
                    city=comp_jobs[k].find_all('span',class_="param-value")[1].text.strip()
                    City.append(city)
                except:
                    City.append("0")
                print(f"{title},{company},{city}")
                k+=1
            except:
                pass
        time.sleep(0.5)
        browser.click_link_by_partial_text(field)
        time.sleep(1)
# Out:
# Dev + Engineer
# Engineering Manager, Data Products,Discord,San Francisco
# Senior Product Designer,Discord,San Francisco
# Data Science Manager,Discord,San Francisco
# Software Engineer (Frontend),Second Measure,Peninsula
# Lead Full Stack Engineer,Cisco Meraki,San Francisco
# Design + UX
# Senior Product Designer,Postmates,San Francisco
# Graphic Designer,Discord,San Francisco
# Product Designer, Growth,Grammarly,San Francisco
# Creative Strategist, Presentations (Contract),Cisco Meraki,San Francisco
# Instructional Designer x2,Cisco Meraki,San Francisco
# Product
# Head of Pay and Time PM,Gusto,San Francisco
# Product Manager, Growth,HomeLight,San Francisco
# Senior Product Manager - Server,CircleCI,San Francisco
# Director of Product Management - Secure SD-WAN,Cisco Meraki,San Francisco
# Product Manager - API & Developer Platform,Cisco Meraki,San Francisco
# Marketing
# Senior Product Marketing Manager,Rally Health,San Francisco
# Content Marketing Manager,Recurly,San Francisco
# Product Marketing Lead, Benefits,Gusto,San Francisco
# Audience Marketing Manager - Commercial/GES,Cisco Meraki,San Francisco
# Product Marketing Manager - Switching,Cisco Meraki,San Francisco
# Data + Analytics
# Senior Data Analyst,Cisco Meraki,San Francisco
# Software Engineer, Database,DoorDash,San Francisco
# Trust & Safety Data Entry Specialist (Contract),Instacart,San Francisco
# Channel Operations Specialist – Partner Support,Cisco Meraki,San Francisco
# Architect, AI Infrastructure,Cisco Meraki,San Francisco
# Finance
# Senior Data Analyst,Cisco Meraki,San Francisco
# Senior Strategic Partnerships Analyst,HomeLight,San Francisco
# Software Engineer, Database,DoorDash,San Francisco
# Channel Operations Specialist – Partner Support,Cisco Meraki,San Francisco
# Architect, AI Infrastructure,Cisco Meraki,San Francisco
# Dev + Engineer
# Training Manager,Knock,Seattle
# Software Engineer, Front End,Knock,Seattle
# Implementation Manager,Knock,Seattle
# Inside Sales Representative,vcita,Bellevue
# Junior Inside Sales Representative,vcita,Bellevue
# Design + UX
# Senior UX Researcher,The Trade Desk,Bellevue
# 3D Artist,Mythical Games,Seattle
# Instructional Designer, E-learning,98point6,Seattle
# Designer (remote),Lightboard,Seattle
# Designer (In-house),Lightboard,Seattle
# Product
# Technical Product Manager - 5G Networks,Pivotal Commware,Kirkland
# Principal Product Manager - Autos (Bellevue),OfferUp,Bellevue
# Senior Product Manager, Data Products,The Trade Desk,Bellevue
# Product Manager,Knock,Seattle
# Technical Product Manager,Luum,Seattle
# Marketing
# Senior Content Marketing Manager, Cloud Services,Unity Technologies,Bellevue
# Senior Product Marketing Manager,Axon,Seattle
# Senior Marketing Manager, Pharmaceutical Solutions,Navigating Cancer,Seattle
# Senior Digital Marketing Manager,Convoy,Seattle
# Product Marketing Manager, Sales Enablement and Content Lead,Convoy,Seattle
# Data + Analytics
# Senior Associate, Digital Marketing,Remitly,Seattle
# Senior Marketing Manager,Ekata,Seattle
# Global Communications Leader,Qualtrics,Seattle
# Senior Digital Marketing Manager,Convoy,Seattle
# Product Marketing Manager, Sales Enablement and Content Lead,Convoy,Seattle
# Finance
# Senior Data Scientist - Convoy Go,Convoy,Seattle
# Lead Senior Data Scientist,The Trade Desk,Bellevue
# Compliance Investigator - Medicare,Assurance,Bellevue
# Research Science Manager - Operations Research,Convoy,Seattle
# Engineering Manager - Data Platform,Convoy,Seattle

# %%
print(len(Field))
print(len(Job_Title))
print(len(Company))
print(len(City))
print(len(Tech_Hub))
# Out:
# 295
# 295
# 295
# 295
# 295

# %%
#used lists to create data frame with appropriate column headers
Job_Results_df = pd.DataFrame({"Category_Name":Field,"Job_Title":Job_Title,"Company":Company,"TechHub_Name":Tech_Hub,"City":City})
Job_Results_df.replace({"chicago":"Chicago","boston":"Boston", "austin": "Austin", "colorado":"Colorado", "nyc":"NYC", "sf":"San Francisco", "seattle":"Seattle","la":"Los Angeles"},inplace = True)
Job_Results_df.head(2)
# Out:
#     Category_Name                            Job_Title   Company TechHub_Name  \
# 0  Dev + Engineer  Senior Software Engineer, Front End  Kalderos      Chicago
# 1  Dev + Engineer     Senior Site Reliability Engineer   Optiver      Chicago
#
#       City
# 0  Chicago
# 1  Chicago

# %%
Job_Results_df["TechHub_Name"].unique()
# Out:
# array(['Chicago', 'Boston', 'Austin', 'Colorado', 'NYC', 'Los Angeles',
#        'San Francisco', 'Seattle'], dtype=object)

# %%
jc = pd.read_csv("Category.csv")
jc2 = jc.rename(columns = {"Unnamed: 0":"JobCategory_ID"})
jc3=jc2["Category_Name"]
jc2
# Out:
#    JobCategory_ID     Category_Name
# 0               0    Dev + Engineer
# 1               1       Design + UX
# 2               2           Product
# 3               3         Marketing
# 4               4           Finance
# 5               5             Sales
# 6               6  Data + Analytics

# %%
th = pd.read_csv("Tech_Hub2.csv")
th2=th[["Unnamed: 0","TechHub_Name"]]
th2=th2.rename(columns = {"Unnamed: 0":"TechHub_ID"})
th2
# Out:
#    TechHub_ID   TechHub_Name
# 0           0         Austin
# 1           1         Boston
# 2           2        Chicago
# 3           3       Colorado
# 4           4    Los Angeles
# 5           5            NYC
# 6           6  San Francisco
# 7           7        Seattle

# %%
JR_2 = Job_Results_df.merge(th2, on = "TechHub_Name")
JR3 = JR_2.merge(jc2, on= "Category_Name")
JR3
# Out:
#         Category_Name                                          Job_Title  \
# 0      Dev + Engineer                Senior Software Engineer, Front End
# 1      Dev + Engineer                   Senior Site Reliability Engineer
# 2      Dev + Engineer                                     Cloud Engineer
# 3      Dev + Engineer                       Sr. Microsoft Cloud Engineer
# 4      Dev + Engineer    Senior Site Reliability Engineer, Observability
# ..                ...                                                ...
# 290  Data + Analytics                Senior Associate, Digital Marketing
# 291  Data + Analytics                           Senior Marketing Manager
# 292  Data + Analytics                       Global Communications Leader
# 293  Data + Analytics                   Senior Digital Marketing Manager
# 294  Data + Analytics  Product Marketing Manager, Sales Enablement an...
#
#           Company TechHub_Name     City  TechHub_ID  JobCategory_ID
# 0        Kalderos      Chicago  Chicago           2               0
# 1         Optiver      Chicago  Chicago           2               0
# 2          Slalom      Chicago  Chicago           2               0
# 3            DFIN      Chicago  Chicago           2               0
# 4    Cisco Meraki      Chicago   Remote           2               0
# ..            ...          ...      ...         ...             ...
# 290       Remitly      Seattle  Seattle           7               6
# 291         Ekata      Seattle  Seattle           7               6
# 292     Qualtrics      Seattle  Seattle           7               6
# 293        Convoy      Seattle  Seattle           7               6
# 294        Convoy      Seattle  Seattle           7               6
#
# [295 rows x 7 columns]

# %%
JobPosting = JR3[["JobCategory_ID","Job_Title","Company","City","TechHub_ID"]]
JobPosting
# Out:
#      JobCategory_ID                                          Job_Title  \
# 0                 0                Senior Software Engineer, Front End
# 1                 0                   Senior Site Reliability Engineer
# 2                 0                                     Cloud Engineer
# 3                 0                       Sr. Microsoft Cloud Engineer
# 4                 0    Senior Site Reliability Engineer, Observability
# ..              ...                                                ...
# 290               6                Senior Associate, Digital Marketing
# 291               6                           Senior Marketing Manager
# 292               6                       Global Communications Leader
# 293               6                   Senior Digital Marketing Manager
# 294               6  Product Marketing Manager, Sales Enablement an...
#
#           Company     City  TechHub_ID
# 0        Kalderos  Chicago           2
# 1         Optiver  Chicago           2
# 2          Slalom  Chicago           2
# 3            DFIN  Chicago           2
# 4    Cisco Meraki   Remote           2
# ..            ...      ...         ...
# 290       Remitly  Seattle           7
# 291         Ekata  Seattle           7
# 292     Qualtrics  Seattle           7
# 293        Convoy  Seattle           7
# 294        Convoy  Seattle           7
#
# [295 rows x 5 columns]

# %%
#JobPosting.to_csv("JobPosting.csv")

# %%
# testing SQLAlchemy insert
#JobPosting.to_sql('jobposting',engine, if_exists= "replace")
