# %%
from bs4 import BeautifulSoup
from splinter import Browser
import time
import requests
import pandas as pd

# %%
executable_path = {'executable_path': 'chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=False)

# %%
#Create lists to hold data to put into columns for a dataframe
Job_Title = []
Company = []
City = []
Field = []
Tech_Hub = []
#loop of Tech Hubs, but changed to 5 because the hubs of sf and seattle don't have the same page structure.
city_loop = ["chicago","boston","austin","colorado","nyc"]
#List of job fields that I wish to click through as I loop through the different Tech Hubs
Fields = ["Data + Analytics","Design","Dev + Engineer","Marketing","Project Mgmt","Product"]
#loop to go through the different tech hubs
for c in city_loop:
    #logic adapt urls based on the tech hub desired. logic to handle the fact that chicago was .org and the rest were .com
    if c in ["chicago"]:
        url =f"https://www.builtin{c}.org/jobs"
    else: 
        url =f"https://www.builtin{c}.com/jobs"
    # browse to the tech hub url
    browser.visit(url)
    # slight delay to let the page load
    time.sleep(0.25)
    #loop to go through and click the different job field options
    for field in Fields:
        #print field <-- I had printed field to track progress and know if it got hung up somewhere. 
        #How I found out sf and seattle didn't function
        #click field buttons
        browser.links.find_by_partial_text(field)
        #pause to let the page load
        time.sleep(3)
        
        #grab the html code of the page
        html = browser.html
        #read and store html as a soup object
        soup = BeautifulSoup(html, 'html.parser')
        #grab all subsections of "left-col" which are the containers with the job postings and store in a list
        comp_jobs = soup.find_all('div', class_="left-col")

        #Loop through the subsections and do so as integers so that list items can be referenced
        for k in range(5):

            #store title, company, and city
            title = comp_jobs[k].find('h2',class_="title").text
            company=comp_jobs[k].find('div',class_="company-title").text
            city=comp_jobs[k].find('div',class_="job-location").text
            #I stored them and printed them to know progress as it was running because it took about 10 minutes to run.
    #                 print(title)
    #                 print(company)
    #                 print(city)
    #                 print(c)
    #                 print("----------------------------")
            #appended lists with each jobs information and at the same time stored current field and tech hub
            Field.append(field)
            Job_Title.append(title)
            Company.append(company)
            City.append(city)
            Tech_Hub.append(c)

# %%
print(len(Field))
print(len(Job_Title))
print(len(Company))
print(len(City))
print(len(Tech_Hub))
# Out:
# 150
# 150
# 150
# 150
# 150

# %%
sf_loop =["sf","seattle"]
for c in sf_loop:
    if c in ["chicago"]:
        url =f"https://www.builtin{c}.org/jobs"
    else: 
        url =f"https://www.builtin{c}.com/jobs"
#     print(url)
    browser.visit(url)
#     print(c)
    time.sleep(0.25)
    for field in Fields:
        browser.links.find_by_partial_text(field)
        time.sleep(3)
        print(field)
       
        html = browser.html
        #read and store html
        soup = BeautifulSoup(html, 'html.parser')
        comp_jobs = soup.find_all('div', class_="condensed-job-row")
            
        for k in range(5):

            title = comp_jobs[k].find('h2', class_="job-title").text

            company=comp_jobs[k].find_all('span',class_="param-value")[0].text.strip()
            city=comp_jobs[k].find_all('span',class_="param-value")[1].text.strip()
            
            Field.append(field)
            Job_Title.append(title)
            Company.append(company)
            City.append(city)
            Tech_Hub.append(c)
# Out:
# Data + Analytics
# Design
# Dev + Engineer
# Marketing
# Project Mgmt
# Product
# Data + Analytics
# Design
# Dev + Engineer
# Marketing
# Project Mgmt
# Product

# %%
print(len(Field))
print(len(Job_Title))
print(len(Company))
print(len(City))
print(len(Tech_Hub))
# Out:
# 210
# 210
# 210
# 210
# 210

# %%
#used lists to create data frame with appropriate column headers
Job_Results_df = pd.DataFrame({"Field":Field,"Job_Title":Job_Title,"Company":Company,"Tech Hub":Tech_Hub,"City":City})
Job_Results_df.head(50)
# Out:
#                Field                                   Job_Title  \
# 0   Data + Analytics       Project Manager - SaaS and Technology
# 1   Data + Analytics                          Head of Accounting
# 2   Data + Analytics                        AWS Cloud Sales Lead
# 3   Data + Analytics                         Technical Recruiter
# 4   Data + Analytics                     Channel Account Manager
# 5             Design       Project Manager - SaaS and Technology
# 6             Design                          Head of Accounting
# 7             Design                        AWS Cloud Sales Lead
# 8             Design                         Technical Recruiter
# 9             Design                     Channel Account Manager
# 10    Dev + Engineer       Project Manager - SaaS and Technology
# 11    Dev + Engineer                          Head of Accounting
# 12    Dev + Engineer                        AWS Cloud Sales Lead
# 13    Dev + Engineer                         Technical Recruiter
# 14    Dev + Engineer                     Channel Account Manager
# 15         Marketing       Project Manager - SaaS and Technology
# 16         Marketing                          Head of Accounting
# 17         Marketing                        AWS Cloud Sales Lead
# 18         Marketing                         Technical Recruiter
# 19         Marketing                     Channel Account Manager
# 20      Project Mgmt       Project Manager - SaaS and Technology
# 21      Project Mgmt                          Head of Accounting
# 22      Project Mgmt                        AWS Cloud Sales Lead
# 23      Project Mgmt                         Technical Recruiter
# 24      Project Mgmt                     Channel Account Manager
# 25           Product       Project Manager - SaaS and Technology
# 26           Product                          Head of Accounting
# 27           Product                        AWS Cloud Sales Lead
# 28           Product                         Technical Recruiter
# 29           Product                     Channel Account Manager
# 30  Data + Analytics                 Client Relationship Manager
# 31  Data + Analytics            Senior Sales Commissions Analyst
# 32  Data + Analytics  Ruby on Rails Developer - Senior/Principal
# 33  Data + Analytics                Enterprise Account Executive
# 34  Data + Analytics         Business Development Representative
# 35            Design                 Client Relationship Manager
# 36            Design            Senior Sales Commissions Analyst
# 37            Design  Ruby on Rails Developer - Senior/Principal
# 38            Design                Enterprise Account Executive
# 39            Design         Business Development Representative
# 40    Dev + Engineer                 Client Relationship Manager
# 41    Dev + Engineer            Senior Sales Commissions Analyst
# 42    Dev + Engineer  Ruby on Rails Developer - Senior/Principal
# 43    Dev + Engineer                Enterprise Account Executive
# 44    Dev + Engineer         Business Development Representative
# 45         Marketing                 Client Relationship Manager
# 46         Marketing            Senior Sales Commissions Analyst
# 47         Marketing  Ruby on Rails Developer - Senior/Principal
# 48         Marketing                Enterprise Account Executive
# 49         Marketing         Business Development Representative
#
#                Company Tech Hub                 City
# 0               Sphera  chicago              Chicago
# 1           Clearcover  chicago              Chicago
# 2           Maven Wave  chicago              Chicago
# 3              Optiver  chicago              Chicago
# 4       ActiveCampaign  chicago              Chicago
# 5               Sphera  chicago              Chicago
# 6           Clearcover  chicago              Chicago
# 7           Maven Wave  chicago              Chicago
# 8              Optiver  chicago              Chicago
# 9       ActiveCampaign  chicago              Chicago
# 10              Sphera  chicago              Chicago
# 11          Clearcover  chicago              Chicago
# 12          Maven Wave  chicago              Chicago
# 13             Optiver  chicago              Chicago
# 14      ActiveCampaign  chicago              Chicago
# 15              Sphera  chicago              Chicago
# 16          Clearcover  chicago              Chicago
# 17          Maven Wave  chicago              Chicago
# 18             Optiver  chicago              Chicago
# 19      ActiveCampaign  chicago              Chicago
# 20              Sphera  chicago              Chicago
# 21          Clearcover  chicago              Chicago
# 22          Maven Wave  chicago              Chicago
# 23             Optiver  chicago              Chicago
# 24      ActiveCampaign  chicago              Chicago
# 25              Sphera  chicago              Chicago
# 26          Clearcover  chicago              Chicago
# 27          Maven Wave  chicago              Chicago
# 28             Optiver  chicago              Chicago
# 29      ActiveCampaign  chicago              Chicago
# 30         MineralTree   boston            Cambridge
# 31              Nuance   boston  Greater Boston Area
# 32      Immersive Labs   boston               Remote
# 33  Thought Industries   boston  Greater Boston Area
# 34  Thought Industries   boston  Greater Boston Area
# 35         MineralTree   boston            Cambridge
# 36              Nuance   boston  Greater Boston Area
# 37      Immersive Labs   boston               Remote
# 38  Thought Industries   boston  Greater Boston Area
# 39  Thought Industries   boston  Greater Boston Area
# 40         MineralTree   boston            Cambridge
# 41              Nuance   boston  Greater Boston Area
# 42      Immersive Labs   boston               Remote
# 43  Thought Industries   boston  Greater Boston Area
# 44  Thought Industries   boston  Greater Boston Area
# 45         MineralTree   boston            Cambridge
# 46              Nuance   boston  Greater Boston Area
# 47      Immersive Labs   boston               Remote
# 48  Thought Industries   boston  Greater Boston Area
# 49  Thought Industries   boston  Greater Boston Area
