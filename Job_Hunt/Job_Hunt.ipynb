# %%
from bs4 import BeautifulSoup
from splinter import Browser
import time
import requests
import pandas as pd

# %% [markdown]
# WINDOWS USERS

# %%
executable_path = {'executable_path': 'chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=False)

# %% [markdown]
# MAC USERS

# %%
url = "https://builtin.com/jobs"
browser.visit(url)
time.sleep(0.25)
browser.click_link_by_partial_text('Data + Analytics')
time.sleep(2)
Job_Title = []
Company = []
City = []
Field = []
for i in range(2):
    html = browser.html
    #read and store html
    soup = BeautifulSoup(html, 'html.parser')
    job_chunk = soup.find_all('div', class_="job-item")

    for i in range(len(job_chunk)):
        comp_jobs = job_chunk[i].find_all('div',class_='condensed-job-row')
        
        for i in range(len(comp_jobs)):

            title = comp_jobs[i].find('h2',class_="job-title").text
            company=comp_jobs[i].find_all('span', class_="param-value")[0].text.strip()
            city=comp_jobs[i].find_all('span', class_="param-value")[1].text.strip()
            print(title)
            print(company)
            print(city)
            print("----------------------------")
            Field.append("Data + Analytics")
            Job_Title.append(title)
            Company.append(company)
            City.append(city)
            
    browser.click_link_by_partial_text('Next')
    time.sleep(6)
# Out:
# C:\Users\walsh\anaconda3\lib\site-packages\splinter\driver\webdriver\__init__.py:528: FutureWarning: browser.find_link_by_partial_text is deprecated. Use browser.links.find_by_partial_text instead.
#   FutureWarning,
# Biomedical Data Scientist, Biostatistician
# PathAI
# Greater Boston Area
# ----------------------------
# Analyst, Tuition Assistance Operations
# Guild Education
# Greater Denver Area
# ----------------------------
# Program Effectiveness Manager
# Outreach
# Seattle
# ----------------------------
# Data Integration Specialist
# Engrain
# Greater Denver Area
# ----------------------------
# Developer Relations Analyst
# LevelTen Energy
# Seattle
# ----------------------------
# Staff Data Engineer Systems & Infrastructure
# Guild Education
# Greater Denver Area
# ----------------------------
# Senior Data Engineer
# Guild Education
# Greater Denver Area
# ----------------------------
# Lead Data Engineer, Data Infrastructure
# Guild Education
# Greater Denver Area
# ...

# %%
print(len(City))
print(len(Company))
print(len(Job_Title))
print(len(Field))
# Out:
# 87
# 87
# 87
# 87

# %%
df= pd.DataFrame({"Field":Field,"Job_Title":Job_Title,"City":City,"Company":Company})
df.head()
# Out:
#               Field                                   Job_Title  \
# 0  Data + Analytics  Biomedical Data Scientist, Biostatistician
# 1  Data + Analytics      Analyst, Tuition Assistance Operations
# 2  Data + Analytics               Program Effectiveness Manager
# 3  Data + Analytics                 Data Integration Specialist
# 4  Data + Analytics                 Developer Relations Analyst
#
#                   City          Company
# 0  Greater Boston Area           PathAI
# 1  Greater Denver Area  Guild Education
# 2              Seattle         Outreach
# 3  Greater Denver Area          Engrain
# 4              Seattle  LevelTen Energy

# %%
html = browser.html
#read and store html
soup = BeautifulSoup(html, 'html.parser')

# %%
df.groupby(City).count()
# Out:
#                       Field  Job_Title  City  Company
# Austin                    8          8     8        8
# Bellevue                  5          5     5        5
# Chicago                   9          9     9        9
# Greater Boston Area      16         16    16       16
# Greater Boulder Area      4          4     4        4
# Greater Denver Area       7          7     7        7
# Greater NYC Area         11         11    11       11
# San Francisco            16         16    16       16
# Seattle                  11         11    11       11

# %%
browser.click_link_by_partial_text('Next')
time.sleep(0.25)

# %%
url = "https://builtin.com/jobs"
browser.visit(url)
time.sleep(0.25)
browser.click_link_by_partial_text('Data + Analytics')

# %%
html = browser.html
soup = BeautifulSoup(html, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html data-n-head="%7B%22lang%22:%7B%221%22:%22en%22%7D%7D" lang="en" xmlns="http://www.w3.org/1999/xhtml">
#  <head>
#   <meta charset="utf-8"/>
#   <script src="https://bam.nr-data.net/1/1490ac5bd8?a=257495599&amp;sa=1&amp;v=1123.df1c7f8&amp;t=Unnamed%20Transaction&amp;rst=710&amp;ref=https://builtin.com/jobs&amp;be=193&amp;fe=661&amp;dc=411&amp;af=err,xhr,stn,ins,spa&amp;perf=%7B%22timing%22:%7B%22of%22:1590779995155,%22n%22:0,%22u%22:173,%22ue%22:173,%22f%22:1,%22dn%22:1,%22dne%22:1,%22c%22:1,%22ce%22:1,%22rq%22:11,%22rp%22:162,%22rpe%22:164,%22dl%22:183,%22di%22:410,%22ds%22:410,%22de%22:411,%22dc%22:660,%22l%22:660,%22le%22:664%7D,%22navigation%22:%7B%7D%7D&amp;jsonp=NREUM.setToken" type="text/javascript">
#   </script>
#   <script src="https://js-agent.newrelic.com/nr-spa-1123.min.js">
#   </script>
#   <script async="" src="https://static.ads-twitter.com/uwt.js" type="text/javascript">
#   </script>
# ...

# %%
job_chunk = soup.find_all('div', class_="job-item")
Job_Title = []
Company = []
City = []
for i in range(len(job_chunk)):
    comp_jobs = job_chunk[i].find_all('div',class_='condensed-job-row')
    print(comp_jobs)
    for i in range(len(comp_jobs)):
        
        title = comp_jobs[i].find('h2',class_="job-title").text
        company=comp_jobs[i].find_all('span', class_="param-value")[0].text.strip()
        city=comp_jobs[i].find_all('span', class_="param-value")[1].text.strip()

        Job_Title.append(title)
        Company.append(company)
        City.append(city)
# Out:
# [<div class="condensed-job-row py-1 col" data-v-74765598=""><h2 class="job-title" data-v-74765598="">Data Engineering Manager</h2> <div class="row basic-info" data-v-74765598=""><div class="icon-label info-label company-title font-weight-bold" data-v-74765598="" data-v-d6abb5a8=""><!-- --> <!-- --> <span class="param-value" data-v-d6abb5a8="">
#         Peloton
# ...

# %%
print(Job_Title)
print(Company)
print(City)
print(len(Job_Title))
print(len(Company))
print(len(City))
# Out:
# ['Data Engineering Manager', 'Biomedical Data Scientist, Biostatistician', 'Senior Data Engineer', 'Machine Learning Engineer (Computer Vision)', 'Business Analyst', 'Data Integration Engineer', 'Market Quality and Quantitative Analyst', 'VP of Data', 'Manager, Data Quality', 'Data Engineer', 'Senior Data Scientist', 'Compliance Investigator - Medicare', 'Lead Senior Data Scientist', 'Senior Data Scientist', 'Software Engineer, Machine Learning', 'Program Effectiveness Manager', 'Principal Software Engineer, Reporting & Analytics', 'Sr. Data Engineer, Business Intelligence', 'Software Engineering Manager, Data Pipeline', 'Principal Data Engineer', 'Health Data Analyst', 'Analytics Services Associate - Sales Development Program', 'Senior Data Analyst (Health Data Management) - Veeva Data Cloud', 'Head of Market Research', 'Digital Business Analyst', 'Investment Systems Engineer', 'Advanced Data Engineer', 'Data Engineer – Advanced', 'Data Engineer - Data Plus Math', 'Marketplace Regul
# ...

# %%
title=alt[0].find('h2',class_="job-title").text
b=alt[0].find_all('span', class_="param-value")[0].text.strip()
c=alt[0].find_all('span', class_="param-value")[1].text.strip()
print(title)
print(b)
print(c)
# print(b[1].text.strip())
# Out:
# Machine Learning Engineer, Data Science
# Atlassian
# San Francisco

# %%
job_title = soup.find_all('h2', class_="job-title")
company = soup.find_all('div', class_="full-job-row")

# %%
job_titles=[]
companies=[]
for i in range(len(job_title)):
    job_titles.append(job_title[i].text)

# %%
jobs = soup.find_all('div', class_="job-item")
Company = []
City = []

# %%
jobs = soup.find_all('div', class_="job-item")
Company = []
City = []
count = 0
for i in range(len(jobs)):
    info = jobs[i].find_all('span', class_="param-value")
    
    if len(jobs[i].find_all('span', class_="param-value")) == 6:
        try:
            comp =info[0].text.replace('\n', "").strip()
            cit=info[1].text.replace('\n', "").strip()
            Company.append(comp)
            City.append(cit)
            count +=1
            print(comp)
            print(cit)
            print("-------------------------")
        except:
            pass
    elif len(jobs[i].find_all('span', class_="param-value")) == 8:
        try:
            Company.append(info[0].text.replace('\n', "").strip())
            City.append(info[1].text.replace('\n', "").strip())
            Company.append(info[6].text.replace('\n', "").strip())
            City.append(info[7].text.replace('\n', "").strip())

        
print(Company)
print(City)
# Out:
# []
# []

# %%
print(len(job_titles))
print(len(Company))
print(len(City))
# Out:
# 70
# 21
# 21

# %%
print(len(jobs[1].find_all('span', class_="param-value")))
print(len(jobs[2].find_all('span', class_="param-value")))
print(len(jobs[4].find_all('span', class_="param-value")))
print(len(jobs[5].find_all('span', class_="param-value")))
print(len(jobs[9].find_all('span', class_="param-value")))
print(len(jobs[6].find_all('span', class_="param-value")))
# Out:
# 6
# 6
# 14
# 8
# 11
# 5

# %%
new = job_item[1].text.strip('\n')

# %% [markdown]
# I didn't like just grabbing information pertaining to Data + Analytics because I realized that we will grab different data for the tech hubs, so I restructured so that instead of scraping the data and analytics job page it would loop through and scrape pages based on the different tech categories.  In doing this I realized that html could change based on the size of the page as it was failing when I reran.  Realized the condensed job class I was utilizing was only available for smaller width pages.  When I shrink the generated browser it works like a charm even though the results aren't what I want.

# %%
url = "https://builtin.com/jobs"
browser.visit(url)
time.sleep(0.25)
Job_Title = []
Company = []
City = []
Field = []

Category_Name=["Data + Engineer", "Design + UX", "Product", "Marketing", "Finance", "Sales", "Data + Analytics"]

for field in Fields:
    browser.links.find_by_partial_text(field)
    time.sleep(2)

    for i in range(10):
        html = browser.html
        #read and store html
        soup = BeautifulSoup(html, 'html.parser')
        job_chunk = soup.find_all('div', class_="job-item")

        for j in range(len(job_chunk)):
            comp_jobs = job_chunk[j].find_all('div',class_='condensed-job-row')

            for k in range(len(comp_jobs)):

                title = comp_jobs[k].find('h2',class_="job-title").text
                company=comp_jobs[k].find_all('span', class_="param-value")[0].text.strip()
                city=comp_jobs[k].find_all('span', class_="param-value")[1].text.strip()
                print(title)
                print(company)
                print(city)
                print("----------------------------")
                Field.append(field)
                Job_Title.append(title)
                Company.append(company)
                City.append(city)

        browser.links.find_by_partial_text('Next')
        time.sleep(3)

# %% [markdown]
# I was disappointed with the results because they only returned 4 main areas only representing Colorado and Seattle, so I restructured in order to obtain jobs from each of the major hubs and categories. A picture of the output I obtained after putting into a df is under only4locations.

# %%
It's going to look for a pattern, standard notation,  find a pattern and replace it. Regex extract, return only the pattern you look for.

# %%
#research of page to find desired scraping paths
a = soup.find_all('div',class_="left-col")
a[0].find('h2',class_="title").text
a[0].find('div',class_="company-title").text
a[0].find('div',class_="job-location").text

# %% [markdown]
# Below is research code for sf and seattle as their pages proved to be structured differently than the other 5 tech hubs

# %%
url ="https://www.builtinsf.com/jobs"
browser.visit(url)
#     print(c)
time.sleep(0.25)
browser.links.find_by_partial_text("Data + Analytics")
time.sleep(2)
html = browser.html
#read and store html
soup = BeautifulSoup(html, 'html.parser')
