# %%
from bs4 import BeautifulSoup
from splinter import Browser
import time
import requests
import pandas as pd

# %%
executable_path = {'executable_path': 'chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=False)

# %%
url = "https://www.builtinchicago.org/jobs"
browser.visit(url)
time.sleep(1)
browser.click_link_by_partial_text('Data')
# Out:
# C:\Users\walsh\anaconda3\lib\site-packages\splinter\driver\webdriver\__init__.py:528: FutureWarning: browser.find_link_by_partial_text is deprecated. Use browser.links.find_by_partial_text instead.
#   FutureWarning,

# %%
#Create lists to hold data to put into columns for a dataframe
Job_Title = []
Company = []
City = []
Field = []
Tech_Hub = []
#loop of Tech Hubs, but changed to 5 because the hubs of sf and seattle don't have the same page structure.
city_loop = ["chicago","boston","austin","colorado","nyc"]
#List of job fields that I wish to click through as I loop through the different Tech Hubs
Fields = ["Dev + Engineer","Design + UX","Product","Marketing","Finance","Sales","Data + Analytics"]

#loop to go through the different tech hubs
for c in city_loop:
    #logic adapt urls based on the tech hub desired. logic to handle the fact that chicago was .org and the rest were .com
    if c in ["chicago"]:
        url =f"https://www.builtin{c}.org/jobs"
    else: 
        url =f"https://www.builtin{c}.com/jobs"
    # browse to the tech hub url
    browser.visit(url)
    # slight delay to let the page load
    time.sleep(1)
    #loop to go through and click the different job field options
    for field in Fields:
        print(field)
        #How I found out sf and seattle didn't function
        #click field buttons
        browser.click_link_by_partial_text(field)
        #pause to let the page load
        time.sleep(2)
        
        #grab the html code of the page
        html = browser.html
        #read and store html as a soup object
        soup = BeautifulSoup(html, 'html.parser')
        #grab all subsections of "left-col" which are the containers with the job postings and store in a list
        comp_jobs = soup.find_all('div', class_="left-col")

        #Loop through the subsections and do so as integers so that list items can be referenced
        for k in range(5):

            #store title, company, and city
            title = comp_jobs[k].find('h2',class_="title").text
            company=comp_jobs[k].find('div',class_="company-title").text
            city=comp_jobs[k].find('div',class_="job-location").text
            #I stored them and printed them to know progress as it was running because it took about 10 minutes to run.
            print(title)
            print(company)
            print(city)
            print(c)
            print("----------------------------")
            #appended lists with each jobs information and at the same time stored current field and tech hub
            Field.append(field)
            Job_Title.append(title)
            Company.append(company)
            City.append(city)
            Tech_Hub.append(c)
        browser.click_link_by_partial_text(field)
        time.sleep(1)
# Out:
# Dev + Engineer
# Software Engineering Manager
# Farmer's Fridge
# Chicago
# chicago
# ----------------------------
# Salesforce – CPQ Solution Architect
# Slalom
# Chicago
# chicago
# ----------------------------
# Software Engineering Manager
# OppLoans
# Chicago
# chicago
# ----------------------------
# Senior .Net Software Engineer – Fullstack
# DocuSign
# Chicago
# chicago
# ----------------------------
# Windows Engineer
# Optiver
# Chicago
# chicago
# ----------------------------
# Design + UX
# UI Designer
# Codal
# Chicago
# chicago
# ----------------------------
# Technical Software Designer - Chicago
# NextCapital
# Chicago
# chicago
# ----------------------------
# Sr. UX Researcher
# Clearcover
# Chicago
# chicago
# ----------------------------
# Senior Product Designer- Remote
# Cameo
# Remote
# chicago
# ----------------------------
# Senior Product Designer
# LogicGate
# Chicago
# chicago
# ----------------------------
# Product
# Senior Product Manager
# Devbridge
# Chicago
# chicago
# ----------------------------
# Senior Director of Product
# Reverb
# Chicago
# chicago
# ----------------------------
# ----------------------------
# Product Manager
# Reonomy
# Greater NYC Area
# nyc
# ----------------------------
# Associate Product Manager
# Imagen Technologies
# Greater NYC Area
# nyc
# ----------------------------
# Senior Product Manager - Data Platform
# Major League Baseball
# Greater NYC Area
# nyc
# ----------------------------
# Senior Technical Product Manager, Mobile & CTV
# DoubleVerify
# Greater NYC Area
# nyc
# ----------------------------
# Marketing
# Communications Lead
# IEX
# Greater NYC Area
# nyc
# ----------------------------
# Senior Partner Marketing Manager
# AB Tasty
# Greater NYC Area
# nyc
# ----------------------------
# Marketing Operations and Analytics Manager
# Cohley
# Greater NYC Area
# nyc
# ----------------------------
# Freelance Social Media Manager
# Wingspan
# Greater NYC Area
# nyc
# ----------------------------
# Growth Marketing Lead
# Wingspan
# Greater NYC Area
# nyc
# ----------------------------
# Finance
# FP&A Director
# Frame.io
# Greater NYC Area
# nyc
# ----------------------------
# Senior Accountant
# MealPal
# Greater NYC Area
# nyc
# ----------------------------
# FP&A Manager
# Betterment
# Greater NYC Area
# nyc
# ----------------------------
# Director, Financial Planning and Analysis
# The Trade Desk
# Greater NYC Area
# nyc
# ----------------------------
# Revenue Operations Manager
# Dashlane
# Greater NYC Area
# nyc
# ----------------------------
# Sales
# Strategic Partnerships - Cloud
# IEX
# Greater NYC Area
# nyc
# ----------------------------
# Financial Services Sales Executive
# AlphaSense
# Greater NYC Area
# nyc
# ----------------------------
# Provider Partnerships Contracting Associate (
# Covera Health
# Greater NYC Area
# nyc
# ----------------------------
# Strategic Account Manager, Jira Align
# Atlassian
# Greater NYC Area
# nyc
# ----------------------------
# Business Development Director – Partnerships
# Unqork
# Greater NYC Area
# nyc
# ----------------------------
# Data + Analytics
# Head of Data Science
# Saturn Cloud
# Remote
# nyc
# ----------------------------
# Junior Developer
# DriveWealth
# Greater NYC Area
# nyc
# ----------------------------
# Senior Data Scientist
# Hopper
# Greater NYC Area
# nyc
# ----------------------------
# Manager of Client Strategy and Analytics
# Bliss Point Media
# Greater NYC Area
# nyc
# ----------------------------
# Software Engineer - Data Engineering
# Addepar
# Greater NYC Area
# nyc
# ----------------------------

# %%
print(len(Field))
print(len(Job_Title))
print(len(Company))
print(len(City))
print(len(Tech_Hub))
# Out:
# 175
# 175
# 175
# 175
# 175

# %%
Fields = ["Dev + Engineer","Design + UX","Product","Marketing","Data + Analytics","Finance"]
sf_loop =["sf","seattle"]
for c in sf_loop:
    if c in ["chicago"]:
        url =f"https://www.builtin{c}.org/jobs"
    else: 
        url =f"https://www.builtin{c}.com/jobs"
#     print(url)
    browser.visit(url)
#     print(c)
    time.sleep(0.25)
    for field in Fields:
        browser.click_link_by_partial_text(field)
        time.sleep(1)
        print(field)
       
        html = browser.html
        #read and store html
        soup = BeautifulSoup(html, 'html.parser')
        comp_jobs = soup.find_all('div', class_="condensed-job-row")
            
        for k in range(5):

            title = comp_jobs[k].find('h2', class_="job-title").text

            company=comp_jobs[k].find_all('span',class_="param-value")[0].text.strip()
            city=comp_jobs[k].find_all('span',class_="param-value")[1].text.strip()
            
            Field.append(field)
            Job_Title.append(title)
            Company.append(company)
            City.append(city)
            Tech_Hub.append(c)
        browser.click_link_by_partial_text(field)
        time.sleep(1.5)
# Out:
# C:\Users\walsh\anaconda3\lib\site-packages\splinter\driver\webdriver\__init__.py:528: FutureWarning: browser.find_link_by_partial_text is deprecated. Use browser.links.find_by_partial_text instead.
#   FutureWarning,
# Dev + Engineer
# Design + UX
# Product
# Marketing
# Data + Analytics
# Finance
# Dev + Engineer
# Design + UX
# Product
# Marketing
# Data + Analytics
# Finance

# %%
url = "https://www.builtinchicago.org/jobs"
browser.visit(url)
time.sleep(1)
browser.click_link_by_partial_text('Data')

# %%
print(len(Field))
print(len(Job_Title))
print(len(Company))
print(len(City))
print(len(Tech_Hub))
# Out:
# 335
# 335
# 335
# 335
# 335

# %%
#used lists to create data frame with appropriate column headers
Job_Results_df = pd.DataFrame({"Category_Name":Field,"Job_Title":Job_Title,"Company":Company,"TechHub_Name":Tech_Hub,"City":City})
Job_Results_df.replace({"chicago":"Chicago","boston":"Boston", "austin": "Austin", "colorado":"Colorado", "nyc":"NYC", "sf":"San Francisco", "seattle":"Seattle"},inplace = True)

# %%
Job_Results_df["TechHub_Name"].unique()
# Out:
# array(['chicago', 'boston', 'austin', 'colorado', 'nyc', 'sf', 'seattle'],
#       dtype=object)

# %%
jc = pd.read_csv("Category.csv")
jc2 = jc.rename(columns = {"Unnamed: 0":"JobCategory_ID"})
jc2
# Out:
#    JobCategory_ID     Category_Name
# 0               0    Dev + Engineer
# 1               1       Design + UX
# 2               2           Product
# 3               3         Marketing
# 4               4           Finance
# 5               5             Sales
# 6               6  Data + Analytics

# %%
th = pd.read_csv("Tech_Hub2.csv")
th2=th[["Unnamed: 0","TechHub_Name"]]
th2
# Out:
#    Unnamed: 0   TechHub_Name
# 0           0         Austin
# 1           1         Boston
# 2           2        Chicago
# 3           3       Colorado
# 4           4    Los Angeles
# 5           5            NYC
# 6           6  San Francisco
# 7           7        Seattle

# %%
th3 = th2.rename(columns = {"Unnamed: 0":"TechHub_ID"})
th3
# Out:
#    TechHub_ID   TechHub_Name
# 0           0         Austin
# 1           1         Boston
# 2           2        Chicago
# 3           3       Colorado
# 4           4    Los Angeles
# 5           5            NYC
# 6           6  San Francisco
# 7           7        Seattle

# %%
JR_2 = Job_Results_df.merge(th3, on = "TechHub_Name")
JR_2
# Out:
#       Category_Name                                  Job_Title  \
# 0    Dev + Engineer               Software Engineering Manager
# 1    Dev + Engineer        Salesforce – CPQ Solution Architect
# 2    Dev + Engineer               Software Engineering Manager
# 3    Dev + Engineer  Senior .Net Software Engineer – Fullstack
# 4    Dev + Engineer                           Windows Engineer
# ..              ...                                        ...
# 330         Finance  Senior Finance Manager - Revenue Analysis
# 331         Finance             Sr. Global Transaction Manager
# 332         Finance                 Director, Revenue Strategy
# 333         Finance                Accounts Payable Specialist
# 334         Finance                         Manager of Revenue
#
#                 Company TechHub_Name      City  TechHub_ID
# 0       Farmer's Fridge      Chicago   Chicago           2
# 1                Slalom      Chicago   Chicago           2
# 2              OppLoans      Chicago   Chicago           2
# 3              DocuSign      Chicago   Chicago           2
# 4               Optiver      Chicago   Chicago           2
# ..                  ...          ...       ...         ...
# 330           Assurance      Seattle  Bellevue           7
# 331           Snap Inc.      Seattle   Seattle           7
# 332               Auth0      Seattle  Bellevue           7
# 333  Unity Technologies      Seattle  Bellevue           7
# 334                Axon      Seattle   Seattle           7
#
# [335 rows x 6 columns]

# %%
JR3 = JR_2.merge(jc2, on= "Category_Name")
JR3
# Out:
#         Category_Name                                          Job_Title  \
# 0      Dev + Engineer                       Software Engineering Manager
# 1      Dev + Engineer                Salesforce – CPQ Solution Architect
# 2      Dev + Engineer                       Software Engineering Manager
# 3      Dev + Engineer          Senior .Net Software Engineer – Fullstack
# 4      Dev + Engineer                                   Windows Engineer
# ..                ...                                                ...
# 330  Data + Analytics                Software Engineer, Machine Learning
# 331  Data + Analytics  Data Scientist, Relevancy Ranking Algorithms -...
# 332  Data + Analytics                      Program Effectiveness Manager
# 333  Data + Analytics                         Back End Software Engineer
# 334  Data + Analytics                               Senior Data Engineer
#
#              Company TechHub_Name      City  TechHub_ID  JobCategory_ID
# 0    Farmer's Fridge      Chicago   Chicago           2               0
# 1             Slalom      Chicago   Chicago           2               0
# 2           OppLoans      Chicago   Chicago           2               0
# 3           DocuSign      Chicago   Chicago           2               0
# 4            Optiver      Chicago   Chicago           2               0
# ..               ...          ...       ...         ...             ...
# 330   Postmates Inc.      Seattle  Bellevue           7               6
# 331     Getty Images      Seattle   Seattle           7               6
# 332         Outreach      Seattle   Seattle           7               6
# 333         98point6      Seattle   Seattle           7               6
# 334         98point6      Seattle   Seattle           7               6
#
# [335 rows x 7 columns]

# %%
JobPosting = JR3[["JobCategory_ID","Job_Title","Company","City","TechHub_ID"]]
JobPosting
# Out:
#      JobCategory_ID                                          Job_Title  \
# 0                 0                       Software Engineering Manager
# 1                 0                Salesforce – CPQ Solution Architect
# 2                 0                       Software Engineering Manager
# 3                 0          Senior .Net Software Engineer – Fullstack
# 4                 0                                   Windows Engineer
# ..              ...                                                ...
# 330               6                Software Engineer, Machine Learning
# 331               6  Data Scientist, Relevancy Ranking Algorithms -...
# 332               6                      Program Effectiveness Manager
# 333               6                         Back End Software Engineer
# 334               6                               Senior Data Engineer
#
#              Company      City  TechHub_ID
# 0    Farmer's Fridge   Chicago           2
# 1             Slalom   Chicago           2
# 2           OppLoans   Chicago           2
# 3           DocuSign   Chicago           2
# 4            Optiver   Chicago           2
# ..               ...       ...         ...
# 330   Postmates Inc.  Bellevue           7
# 331     Getty Images   Seattle           7
# 332         Outreach   Seattle           7
# 333         98point6   Seattle           7
# 334         98point6   Seattle           7
#
# [335 rows x 5 columns]

# %%
JobPosting.to_csv("JobPosting.csv")
