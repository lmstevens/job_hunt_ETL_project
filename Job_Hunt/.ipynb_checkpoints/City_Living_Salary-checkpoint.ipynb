# %% [markdown]
# COLLECTING AVERAGE LIVING COSTS, AVERAGE SALARY IN 8 FIELDS, AND THE MOST POPULAR TECH FIELDS PER TECHHUB.

# %%
from bs4 import BeautifulSoup
from splinter import Browser
import time
import requests
import os
from selenium import webdriver
import pandas as pd

# %%
url = "https://builtin.com/tech-hubs"
browser = webdriver.Chrome()
browser.get(url)
time.sleep(10)
html = browser.page_source
soup = BeautifulSoup(html, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="js" dir="ltr" lang="en" prefix="content: http://purl.org/rss/1.0/modules/content/ dc: http://purl.org/dc/terms/ foaf: http://xmlns.com/foaf/0.1/ og: http://ogp.me/ns# rdfs: http://www.w3.org/2000/01/rdf-schema# schema: http://schema.org/ sioc: http://rdfs.org/sioc/ns# sioct: http://rdfs.org/sioc/types# skos: http://www.w3.org/2004/02/skos/core# xsd: http://www.w3.org/2001/XMLSchema# " xmlns="http://www.w3.org/1999/xhtml">
#  <head>
#   <meta charset="utf-8"/>
#   <script src="https://pi.pardot.com/pd.js" type="text/javascript">
#   </script>
#   <script async="" src="https://www.google-analytics.com/gtm/js?id=GTM-WN85SW2&amp;cid=86087807.1590947984&amp;aip=true" type="text/javascript">
#   </script>
#   <script async="" src="https://static.ads-twitter.com/uwt.js" type="text/javascript">
#   </script>
#   <script async="" src="https://www.google-analytics.com/analytics.js" type="text/javascript">
#   </script>
# ...

# %%
#click link to tech hubs selenium full xpath code
#browser.find_element_by_xpath("""/html/body/div[1]/div/header/div/div/div/div/div[1]/div[1]/div/div[2]/div/div/div[1]/div[3]/a""").click()

# %%
#find and collect all cities listed on page
cities = browser.find_elements_by_xpath('//div[@class="block block-techhub-cost-block"]//div[@class="block-content"]//div[@class="widget"]//div[@class="title"]')

cities2 = []

for i in range(len(cities)):
    cities2.append(cities[i].text)

del cities2[1::2]
print(cities2)
# Out:
# ['Austin', 'Boston', 'Chicago', 'Colorado', 'Los Angeles', 'NYC', 'San Francisco', 'Seattle']

# %%
#find and collect all cities and their cost of living for 1 bedroom 

living_cost = browser.find_elements_by_xpath('//div[@class="block block-techhub-cost-block"]//div[@class="block-content"]//div[@class="widget"]//div[@class="living-data"]//div[@class="living rent"]//div[@class="value"]')

living_cost2 = []

for i in range(len(living_cost)):
    living_cost2.append(living_cost[i].text)

del living_cost2[1::2]
print(living_cost2)
# Out:
# ['$1,329', '$2,440', '$1,504', '$1,568', '$2,293', '$2,299', '$4,526', '$1,878']

# %%
#find and collect all cities and their cost of avg lunch

lunch_cost = browser.find_elements_by_xpath('//div[@class="block block-techhub-cost-block"]//div[@class="block-content"]//div[@class="widget"]//div[@class="living-data"]//div[@class="living lunch"]//div[@class="value"]')

lunch_cost2 = []

for i in range(len(lunch_cost)):
    lunch_cost2.append(lunch_cost[i].text)

del lunch_cost2[1::2]
print(lunch_cost2)
# Out:
# ['$14', '$15', '$15', '$14', '$17', '$20', '$15', '$16']

# %%
#find and collect all cities and their median home price

home_cost = browser.find_elements_by_xpath('//div[@class="block block-techhub-cost-block"]//div[@class="block-content"]//div[@class="widget"]//div[@class="living-data"]//div[@class="living home-price"]//div[@class="value"]')

home_cost2 = []

for i in range(len(home_cost)):
    home_cost2.append(home_cost[i].text)

del home_cost2[1::2]
print(home_cost2)
# Out:
# ['$371,900', '$592,300', '$226,500', '$421,400', '$689,700', '$671,700', '$1,355,200', '$714,100']

# %%
#find and collect all cities populations

population = browser.find_elements_by_xpath('//div[@class="block block-techhub-all-block"]//div[@class="views-field views-field-population"]//div[@class="field-content"]')

pop2 = []

for i in range(len(population)):
    pop2.append(population[i].text)

print(pop2)
# Out:
# ['950,715', '698898', '2749360', '5770000', '3946000', '8558000', '884363', '755745']

# %%
#number of tech companies per city

tech_comp = browser.find_elements_by_xpath('//div[@class="block block-techhub-all-block"]//div[@class="views-field views-field-companies-number"]//div[@class="field-content"]')

tech_comp2 = []

for i in range(len(tech_comp)):
    tech_comp2.append(tech_comp[i].text)

print(tech_comp2)
# Out:
# ['2,680', '2335', '6003', '3939', '6106', '5243', '4362', '2155']

# %%
#most popular fields of tech in each city

popular_fields = browser.find_elements_by_xpath('//div[@class="views-field views-field-field-th-industries"]//div[@class="paragraph paragraph--type--tech-hub-industry paragraph--view-mode--default"]//div[@class="field--name-field-th-industry-name field--type-string field__item"]')       

popular_fields2 = []

for i in range(len(popular_fields)):
    popular_fields2.append(popular_fields[i].text)

print(popular_fields2)
# Out:
# ['eCommerce', 'Software', 'Cloud', 'Edtech', 'Hardware', 'Security', 'Fintech', 'Healthtech', 'Big Data', 'Software', 'Adtech', 'Mobile', 'Consumer Web', 'Digital Media', 'eCommerce', 'Real Estate', 'Fintech', 'Digital Media', 'Fintech', 'Artificial Intelligence', 'Software', 'Marketing Tech', 'Healthtech']

# %%
pop_field = pd.DataFrame({"popular_fields2":popular_fields2})
pop_field2 = pop_field.popular_fields2.unique()
#len(popular_fields2)
pop_field2
# Out:
# array(['eCommerce', 'Software', 'Cloud', 'Edtech', 'Hardware', 'Security',
#        'Fintech', 'Healthtech', 'Big Data', 'Adtech', 'Mobile',
#        'Consumer Web', 'Digital Media', 'Real Estate',
#        'Artificial Intelligence', 'Marketing Tech'], dtype=object)

# %%
list = []

for c in cities2:
    if c == "San Francisco":
        list.append(c)
        list.append(c)
    else:
        list.append(c)
        list.append(c)
        list.append(c)
        
list

df3 = pd.DataFrame({"TechHub_Name":list, "Popular Industry":popular_fields2})
#df3

df4 = df3.groupby(["TechHub_Name","Popular Industry"])
df4.count()
# Out:
# Empty DataFrame
# Columns: []
# Index: [(Austin, Cloud), (Austin, Software), (Austin, eCommerce), (Boston, Edtech), (Boston, Hardware), (Boston, Security), (Chicago, Big Data), (Chicago, Fintech), (Chicago, Healthtech), (Colorado, Adtech), (Colorado, Mobile), (Colorado, Software), (Los Angeles, Consumer Web), (Los Angeles, Digital Media), (Los Angeles, eCommerce), (NYC, Digital Media), (NYC, Fintech), (NYC, Real Estate), (San Francisco, Artificial Intelligence), (San Francisco, Fintech), (Seattle, Healthtech), (Seattle, Marketing Tech), (Seattle, Software)]

# %%
#Combing all found data above and putting it into a clean DataFrame

TechHub = pd.DataFrame({"TechHub_Name":cities2,"Rent_OneBedroom":living_cost2,"Lunch_Price":lunch_cost2,"Median_HomePrice":home_cost2,"Population":pop2, "Number_TechCompanies":tech_comp2})
TechHub
# Out:
#     TechHub_Name Rent_OneBedroom Lunch_Price Median_HomePrice Population  \
# 0         Austin          $1,329         $14         $371,900    950,715
# 1         Boston          $2,440         $15         $592,300     698898
# 2        Chicago          $1,504         $15         $226,500    2749360
# 3       Colorado          $1,568         $14         $421,400    5770000
# 4    Los Angeles          $2,293         $17         $689,700    3946000
# 5            NYC          $2,299         $20         $671,700    8558000
# 6  San Francisco          $4,526         $15       $1,355,200     884363
# 7        Seattle          $1,878         $16         $714,100     755745
#
#   Number_TechCompanies
# 0                2,680
# 1                 2335
# 2                 6003
# 3                 3939
# 4                 6106
# 5                 5243
# 6                 4362
# 7                 2155

# %%
#Webscrapping Average Salaries by Category in Austin

url2 = "https://builtinaustin.com/salaries"
browser = webdriver.Chrome()
browser.get(url2)
time.sleep(2)
html = browser.page_source
soup = BeautifulSoup(html, 'html.parser')
Austin_fields = soup.find_all('span', class_="field-content")
#austin_fields

field_title = []
field_price = []

for c in range(len(Austin_fields)):
    title = Austin_fields[c].find("div", class_="field-title").text
    price = Austin_fields[c].find("div", class_="field-price").text
    #print(title)
    #print(price)
    #print("----------")
    field_title.append(title)
    field_price.append(price)
    
Austin_df = pd.DataFrame({"Category_Name":field_title,"Avg Salary":field_price})
Austin_df
# Out:
#       Category_Name Avg Salary
# 0    Dev + Engineer   $125,808
# 1       Design + UX   $103,075
# 2           Product   $126,508
# 3         Marketing    $96,128
# 4           Finance   $109,455
# 5             Sales    $80,982
# 6  Data + Analytics   $106,893

# %%
Austin_df2 = pd.DataFrame({"TechHub_Name":cities2[0],"Category_Name":field_title,"Avg Salary":field_price})
Austin_df2
# Out:
#   TechHub_Name     Category_Name Avg Salary
# 0       Austin    Dev + Engineer   $125,808
# 1       Austin       Design + UX   $103,075
# 2       Austin           Product   $126,508
# 3       Austin         Marketing    $96,128
# 4       Austin           Finance   $109,455
# 5       Austin             Sales    $80,982
# 6       Austin  Data + Analytics   $106,893

# %%
Austin_df3 = pd.DataFrame({'TechHub_Name':["Austin"],
                    'Dev + Engineer': ['$125,808'], 'Design + UX':['$103,075'],'Product':['$126,508'],
                           'Marketing':['$96,128'],'Finance':['$109,455'], 'Sales':['$80,982'], 
                           'Data + Analytics':['$106,893']})
Austin_df3
# Out:
#   TechHub_Name Dev + Engineer Design + UX   Product Marketing   Finance  \
# 0       Austin       $125,808    $103,075  $126,508   $96,128  $109,455
#
#      Sales Data + Analytics
# 0  $80,982         $106,893

# %%
#Webscrapping Average Salaries by Category in Boston

url3 = "https://www.builtinboston.com//salaries"
browser = webdriver.Chrome()
browser.get(url3)
time.sleep(2)
html = browser.page_source
soup = BeautifulSoup(html, 'html.parser')
Boston_fields = soup.find_all('span', class_="field-content")
#Boston_fields

field_title = []
field_price = []

for c in range(len(Boston_fields)):
    title = Boston_fields[c].find("div", class_="field-title").text
    price = Boston_fields[c].find("div", class_="field-price").text
    #print(title)
    #print(price)
    #print("----------")
    field_title.append(title)
    field_price.append(price)
    
Boston_df = pd.DataFrame({"Category_Name":field_title,"Avg Salary":field_price})
Boston_df
# Out:
#       Category_Name Avg Salary
# 0    Dev + Engineer   $127,741
# 1       Design + UX   $111,524
# 2           Product   $138,685
# 3         Marketing   $120,244
# 4           Finance   $126,181
# 5             Sales    $90,887
# 6  Data + Analytics   $106,290

# %%
Boston_df2 = pd.DataFrame({"TechHub_Name":cities2[1],"Category_Name":field_title,"Avg Salary":field_price})
Boston_df2
# Out:
#   TechHub_Name     Category_Name Avg Salary
# 0       Boston    Dev + Engineer   $127,741
# 1       Boston       Design + UX   $111,524
# 2       Boston           Product   $138,685
# 3       Boston         Marketing   $120,244
# 4       Boston           Finance   $126,181
# 5       Boston             Sales    $90,887
# 6       Boston  Data + Analytics   $106,290

# %%
Boston_df3 = pd.DataFrame({'TechHub_Name':["Boston"],
                    'Dev + Engineer': ['$127,741'], 'Design + UX':['$111,524'],'Product':['$138,685'],
                           'Marketing':['$120,244'],'Finance':['$126,181'], 'Sales':['$90,887'], 
                           'Data + Analytics':['$106,290']})
Boston_df3
# Out:
#   TechHub_Name Dev + Engineer Design + UX   Product Marketing   Finance  \
# 0       Boston       $127,741    $111,524  $138,685  $120,244  $126,181
#
#      Sales Data + Analytics
# 0  $90,887         $106,290

# %%
#Webscrapping Average Salaries by Category in Chicago

url4 = "https://www.builtinchicago.org/salaries"
browser = webdriver.Chrome()
browser.get(url4)
time.sleep(2)
html = browser.page_source
soup = BeautifulSoup(html, 'html.parser')
Chicago_fields = soup.find_all('span', class_="field-content")
#Chicago_fields

field_title = []
field_price = []

for c in range(len(Chicago_fields)):
    title = Chicago_fields[c].find("div", class_="field-title").text
    price = Chicago_fields[c].find("div", class_="field-price").text
    #print(title)
    #print(price)
    #print("----------")
    field_title.append(title)
    field_price.append(price)
    
Chicago_df = pd.DataFrame({"Category_Name":field_title,"Avg Salary":field_price})
Chicago_df
# Out:
#       Category_Name Avg Salary
# 0    Dev + Engineer   $123,880
# 1       Design + UX    $96,786
# 2           Product   $125,444
# 3         Marketing    $96,598
# 4           Finance   $111,507
# 5             Sales    $89,642
# 6  Data + Analytics   $103,817

# %%
Chicago_df2 = pd.DataFrame({"TechHub_Name":cities2[2],"Category_Name":field_title,"Avg Salary":field_price})
Chicago_df2
# Out:
#   TechHub_Name     Category_Name Avg Salary
# 0      Chicago    Dev + Engineer   $123,880
# 1      Chicago       Design + UX    $96,786
# 2      Chicago           Product   $125,444
# 3      Chicago         Marketing    $96,598
# 4      Chicago           Finance   $111,507
# 5      Chicago             Sales    $89,642
# 6      Chicago  Data + Analytics   $103,817

# %%
Chicago_df3 = pd.DataFrame({'TechHub_Name':["Chicago"],
                    'Dev + Engineer': ['$123,880'], 'Design + UX':['$96,786'],'Product':['$125,444'],
                           'Marketing':['$96,598'],'Finance':['$111,507'], 'Sales':['$89,642'], 
                           'Data + Analytics':['$103,817']})
Chicago_df3
# Out:
#   TechHub_Name Dev + Engineer Design + UX   Product Marketing   Finance  \
# 0      Chicago       $123,880     $96,786  $125,444   $96,598  $111,507
#
#      Sales Data + Analytics
# 0  $89,642         $103,817

# %%
#Webscrapping Average Salaries by Category in Colorado

url5 = "https://www.builtincolorado.com//salaries"
browser = webdriver.Chrome()
browser.get(url5)
time.sleep(2)
html = browser.page_source
soup = BeautifulSoup(html, 'html.parser')
Colorado_fields = soup.find_all('span', class_="field-content")
#Colorado_fields

field_title = []
field_price = []

for c in range(len(Colorado_fields)):
    title = Colorado_fields[c].find("div", class_="field-title").text
    price = Colorado_fields[c].find("div", class_="field-price").text
    #print(title)
    #print(price)
    #print("----------")
    field_title.append(title)
    field_price.append(price)
    
Colorado_df = pd.DataFrame({"Category_Name":field_title,"Avg Salary":field_price})
Colorado_df
# Out:
#       Category_Name Avg Salary
# 0    Dev + Engineer   $114,849
# 1       Design + UX    $92,056
# 2           Product   $113,101
# 3         Marketing    $84,063
# 4           Finance   $105,334
# 5             Sales    $76,160
# 6  Data + Analytics    $99,918

# %%
Colorado_df2 = pd.DataFrame({"TechHub_Name":cities2[3],"Category_Name":field_title,"Avg Salary":field_price})
Colorado_df2
# Out:
#   TechHub_Name     Category_Name Avg Salary
# 0     Colorado    Dev + Engineer   $114,849
# 1     Colorado       Design + UX    $92,056
# 2     Colorado           Product   $113,101
# 3     Colorado         Marketing    $84,063
# 4     Colorado           Finance   $105,334
# 5     Colorado             Sales    $76,160
# 6     Colorado  Data + Analytics    $99,918

# %%
Colorado_df3 = pd.DataFrame({'TechHub_Name':["Colorado"],
                    'Dev + Engineer': ['$114,849'], 'Design + UX':['$92,056'],'Product':['$113,101'],
                           'Marketing':['$84,063'],'Finance':['$105,334'], 'Sales':['$76,160'], 
                           'Data + Analytics':['$99,918']})
Colorado_df3
# Out:
#   TechHub_Name Dev + Engineer Design + UX   Product Marketing   Finance  \
# 0     Colorado       $114,849     $92,056  $113,101   $84,063  $105,334
#
#      Sales Data + Analytics
# 0  $76,160          $99,918

# %%
#Webscrapping Average Salaries by Category in la

url6 = "https://www.builtinla.com/salaries"
browser = webdriver.Chrome()
browser.get(url6)
time.sleep(2)
html = browser.page_source
soup = BeautifulSoup(html, 'html.parser')
la_fields = soup.find_all('span', class_="field-content")
#la_fields

field_title = []
field_price = []

for c in range(len(la_fields)):
    title = la_fields[c].find("div", class_="field-title").text
    price = la_fields[c].find("div", class_="field-price").text
    #print(title)
    #print(price)
    #print("----------")
    field_title.append(title)
    field_price.append(price)
    
la_df = pd.DataFrame({"Category_Name":field_title,"Avg Salary":field_price})
la_df
# Out:
#       Category_Name Avg Salary
# 0    Dev + Engineer   $135,399
# 1       Design + UX   $106,052
# 2           Product   $133,334
# 3         Marketing   $101,956
# 4           Finance   $122,362
# 5             Sales    $95,601
# 6  Data + Analytics   $112,475

# %%
la_df2 = pd.DataFrame({"TechHub_Name":cities2[4],"Category_Name":field_title,"Avg Salary":field_price})
la_df2
# Out:
#   TechHub_Name     Category_Name Avg Salary
# 0  Los Angeles    Dev + Engineer   $135,399
# 1  Los Angeles       Design + UX   $106,052
# 2  Los Angeles           Product   $133,334
# 3  Los Angeles         Marketing   $101,956
# 4  Los Angeles           Finance   $122,362
# 5  Los Angeles             Sales    $95,601
# 6  Los Angeles  Data + Analytics   $112,475

# %%
la_df3 = pd.DataFrame({'TechHub_Name':["Los Angeles"],
                    'Dev + Engineer': ['$135,399'], 'Design + UX':['$106,052'],'Product':['$133,334'],
                           'Marketing':['$101,956'],'Finance':['$122,362'], 'Sales':['$95,601'], 
                           'Data + Analytics':['$112,475']})
la_df3
# Out:
#   TechHub_Name Dev + Engineer Design + UX   Product Marketing   Finance  \
# 0  Los Angeles       $135,399    $106,052  $133,334  $101,956  $122,362
#
#      Sales Data + Analytics
# 0  $95,601         $112,475

# %%
#Webscrapping Average Salaries by Category in nyc

url7 = "https://www.builtinnyc.com/salaries"
browser = webdriver.Chrome()
browser.get(url7)
time.sleep(2)
html = browser.page_source
soup = BeautifulSoup(html, 'html.parser')
nyc_fields = soup.find_all('span', class_="field-content")
#nyc_fields

field_title = []
field_price = []

for c in range(len(nyc_fields)):
    title = nyc_fields[c].find("div", class_="field-title").text
    price = nyc_fields[c].find("div", class_="field-price").text
    #print(title)
    #print(price)
    #print("----------")
    field_title.append(title)
    field_price.append(price)
    
nyc_df = pd.DataFrame({"Category_Name":field_title,"Avg Salary":field_price})
nyc_df
# Out:
#       Category_Name Avg Salary
# 0    Dev + Engineer   $141,021
# 1       Design + UX   $115,983
# 2           Product   $143,385
# 3         Marketing   $106,217
# 4           Finance   $121,080
# 5             Sales    $97,993
# 6  Data + Analytics   $120,117

# %%
nyc_df2 = pd.DataFrame({"TechHub_Name":cities2[5],"Category_Name":field_title,"Avg Salary":field_price})
nyc_df2
# Out:
#   TechHub_Name     Category_Name Avg Salary
# 0          NYC    Dev + Engineer   $141,021
# 1          NYC       Design + UX   $115,983
# 2          NYC           Product   $143,385
# 3          NYC         Marketing   $106,217
# 4          NYC           Finance   $121,080
# 5          NYC             Sales    $97,993
# 6          NYC  Data + Analytics   $120,117

# %%
NYC_df3 = pd.DataFrame({'TechHub_Name':["NYC"],
                    'Dev + Engineer': ['$141,021'], 'Design + UX':['$115,983'],'Product':['$143,385'],
                           'Marketing':['$106,217'],'Finance':['$121,080'], 'Sales':['$97,993'], 
                           'Data + Analytics':['$120,117']})
NYC_df3
# Out:
#   TechHub_Name Dev + Engineer Design + UX   Product Marketing   Finance  \
# 0          NYC       $141,021    $115,983  $143,385  $106,217  $121,080
#
#      Sales Data + Analytics
# 0  $97,993         $120,117

# %%
#Webscrapping Average Salaries by Category in SF

url8 = "https://www.builtinsf.com/salaries"
browser = webdriver.Chrome()
browser.get(url8)
time.sleep(2)
html = browser.page_source
soup = BeautifulSoup(html, 'html.parser')
sf_fields = soup.find_all('span', class_="field-content")
#sf_fields

field_title = []
field_price = []

for c in range(len(sf_fields)):
    title = sf_fields[c].find("div", class_="field-title").text
    price = sf_fields[c].find("div", class_="field-price").text
    #print(title)
    #print(price)
    #print("----------")
    field_title.append(title)
    field_price.append(price)
    
sf_df = pd.DataFrame({"Category_Name":field_title,"Avg Salary":field_price})
sf_df
# Out:
#       Category_Name Avg Salary
# 0             Sales   $130,187
# 1           Finance   $161,398
# 2  Data + Analytics   $144,804
# 3    Dev + Engineer   $162,254
# 4       Design + UX   $154,177
# 5         Marketing   $124,943
# 6           Product   $169,938

# %%
sf_df2 = pd.DataFrame({"TechHub_Name":cities2[6],"Category_Name":field_title,"Avg Salary":field_price})
sf_df2
# Out:
#     TechHub_Name     Category_Name Avg Salary
# 0  San Francisco             Sales   $130,187
# 1  San Francisco           Finance   $161,398
# 2  San Francisco  Data + Analytics   $144,804
# 3  San Francisco    Dev + Engineer   $162,254
# 4  San Francisco       Design + UX   $154,177
# 5  San Francisco         Marketing   $124,943
# 6  San Francisco           Product   $169,938

# %%
sf_df3 = pd.DataFrame({'TechHub_Name':["San Francisco"],
                    'Dev + Engineer': ['$162,254'], 'Design + UX':['$154,177'],'Product':['$169,938'],
                           'Marketing':['$124,943'],'Finance':['$161,398'], 'Sales':['$130,187'], 
                           'Data + Analytics':['$144,804']})
sf_df3
# Out:
#     TechHub_Name Dev + Engineer Design + UX   Product Marketing   Finance  \
# 0  San Francisco       $162,254    $154,177  $169,938  $124,943  $161,398
#
#       Sales Data + Analytics
# 0  $130,187         $144,804

# %%
#Webscrapping Average Salaries by Category in Seattle

url9 = "https://www.builtinseattle.com/salaries"
browser = webdriver.Chrome()
browser.get(url9)
time.sleep(2)
html = browser.page_source
soup = BeautifulSoup(html, 'html.parser')
Seattle_fields = soup.find_all('span', class_="field-content")
#Seattle_fields

field_title = []
field_price = []

for c in range(len(Seattle_fields)):
    title = Seattle_fields[c].find("div", class_="field-title").text
    price = Seattle_fields[c].find("div", class_="field-price").text
    #print(title)
    #print(price)
    #print("----------")
    field_title.append(title)
    field_price.append(price)
    
Seattle_df = pd.DataFrame({"Category_Name":field_title,"Avg Salary":field_price})
Seattle_df
# Out:
#       Category_Name Avg Salary
# 0    Dev + Engineer   $137,240
# 1       Design + UX   $113,419
# 2           Product   $135,510
# 3         Marketing   $104,581
# 4           Finance   $109,808
# 5             Sales    $90,755
# 6  Data + Analytics   $118,251

# %%
Seattle_df2 = pd.DataFrame({"TechHub_Name":cities2[7],"Category_Name":field_title,"Avg Salary":field_price})
Seattle_df2
#print(field_price)
# Out:
#   TechHub_Name     Category_Name Avg Salary
# 0      Seattle    Dev + Engineer   $137,240
# 1      Seattle       Design + UX   $113,419
# 2      Seattle           Product   $135,510
# 3      Seattle         Marketing   $104,581
# 4      Seattle           Finance   $109,808
# 5      Seattle             Sales    $90,755
# 6      Seattle  Data + Analytics   $118,251

# %%
Seattle_df3 = pd.DataFrame({'TechHub_Name':["Seattle"],
                    'Dev + Engineer': ['$137,240'], 'Design + UX':['$113,419'],'Product':['$135,510'],
                           'Marketing':['$104,581'],'Finance':['$109,808'], 'Sales':['$90,755'], 
                           'Data + Analytics':['$118,251']})
Seattle_df3
# Out:
#   TechHub_Name Dev + Engineer Design + UX   Product Marketing   Finance  \
# 0      Seattle       $137,240    $113,419  $135,510  $104,581  $109,808
#
#      Sales Data + Analytics
# 0  $90,755         $118,251

# %%
#merging all data collected from first DataFrames tables

merge_df = Austin_df.merge(Boston_df, on='Category_Name')
merge_df
one = merge_df.rename(columns={"Avg Salary_x":"Austin", "Avg Salary_y":"Boston"})
#one

merge_df2 = one.merge(Chicago_df, on='Category_Name')
merge_df2
two = merge_df2.rename(columns={"Avg Salary": "Chicago"})
#two

merge_df3 = two.merge(Colorado_df, on='Category_Name')
merge_df3
three = merge_df3.rename(columns={"Avg Salary": "Colorado"})
#three

merge_df4 = three.merge(la_df, on='Category_Name')
merge_df4
four = merge_df4.rename(columns={"Avg Salary": "Los Angeles"})
#four

merge_df5 = four.merge(nyc_df, on='Category_Name')
merge_df5
five = merge_df5.rename(columns={"Avg Salary": "NYC"})
#five

merge_df6 = five.merge(sf_df, on='Category_Name')
merge_df6
six = merge_df6.rename(columns={"Avg Salary": "San Francisco"})
#six

merge_df7 = six.merge(Seattle_df, on='Category_Name')
merge_df7
seven = merge_df7.rename(columns={"Avg Salary": "Seattle"})
#seven

# %%
#Data with Category_Name for the rows and TechHub for columns

eight = seven.set_index('Category_Name')
eight
# Out:
#                     Austin    Boston   Chicago  Colorado Los Angeles  \
# Category_Name
# Dev + Engineer    $125,808  $127,741  $123,880  $114,849    $135,399
# Design + UX       $103,075  $111,524   $96,786   $92,056    $106,052
# Product           $126,508  $138,685  $125,444  $113,101    $133,334
# Marketing          $96,128  $120,244   $96,598   $84,063    $101,956
# Finance           $109,455  $126,181  $111,507  $105,334    $122,362
# Sales              $80,982   $90,887   $89,642   $76,160     $95,601
# Data + Analytics  $106,893  $106,290  $103,817   $99,918    $112,475
#
#                        NYC San Francisco   Seattle
# Category_Name
# Dev + Engineer    $141,021      $162,254  $137,240
# Design + UX       $115,983      $154,177  $113,419
# Product           $143,385      $169,938  $135,510
# Marketing         $106,217      $124,943  $104,581
# Finance           $121,080      $161,398  $109,808
# Sales              $97,993      $130,187   $90,755
# ...

# %%
#Flipping axis of previous data set

combo_df = Austin_df3.append(Boston_df3)
#combo_df
combo_df2 = combo_df.append(Chicago_df3)
combo_df3 = combo_df2.append(Colorado_df3)
combo_df4 = combo_df3.append(la_df3)
combo_df5 = combo_df4.append(NYC_df3)
combo_df6 = combo_df5.append(sf_df3)
combo_df7 = combo_df6.append(Seattle_df3)

#combo_df7

# %%
#Data with TechHub for the rows and Category_Name for columns

combo_df8 = combo_df7.set_index('TechHub_Name')
combo_df8
# Out:
#               Dev + Engineer Design + UX   Product Marketing   Finance  \
# TechHub_Name
# Austin              $125,808    $103,075  $126,508   $96,128  $109,455
# Boston              $127,741    $111,524  $138,685  $120,244  $126,181
# Chicago             $123,880     $96,786  $125,444   $96,598  $111,507
# Colorado            $114,849     $92,056  $113,101   $84,063  $105,334
# Los Angeles         $135,399    $106,052  $133,334  $101,956  $122,362
# NYC                 $141,021    $115,983  $143,385  $106,217  $121,080
# San Francisco       $162,254    $154,177  $169,938  $124,943  $161,398
# Seattle             $137,240    $113,419  $135,510  $104,581  $109,808
#
#                   Sales Data + Analytics
# TechHub_Name
# Austin          $80,982         $106,893
# Boston          $90,887         $106,290
# Chicago         $89,642         $103,817
# Colorado        $76,160          $99,918
# Los Angeles     $95,601         $112,475
# NYC             $97,993         $120,117
# ...

# %%
#data with every TechHub listed along next to Category_Name and corresponding Salary

a_df = Austin_df2.append(Boston_df2)
#combo_df
b_df = a_df.append(Chicago_df2)
c_df = b_df.append(Colorado_df2)
d_df = c_df.append(la_df2)
e_df = d_df.append(nyc_df2)
f_df = e_df.append(sf_df2)
Salary_df = f_df.append(Seattle_df2)

Salary_df
# Out:
#     TechHub_Name     Category_Name Avg Salary
# 0         Austin    Dev + Engineer   $125,808
# 1         Austin       Design + UX   $103,075
# 2         Austin           Product   $126,508
# 3         Austin         Marketing    $96,128
# 4         Austin           Finance   $109,455
# 5         Austin             Sales    $80,982
# 6         Austin  Data + Analytics   $106,893
# 0         Boston    Dev + Engineer   $127,741
# 1         Boston       Design + UX   $111,524
# 2         Boston           Product   $138,685
# 3         Boston         Marketing   $120,244
# 4         Boston           Finance   $126,181
# 5         Boston             Sales    $90,887
# 6         Boston  Data + Analytics   $106,290
# 0        Chicago    Dev + Engineer   $123,880
# 1        Chicago       Design + UX    $96,786
# 2        Chicago           Product   $125,444
# 3        Chicago         Marketing    $96,598
# 4        Chicago           Finance   $111,507
# ...

# %%
print(df3.head())
#pop_field_3 = pd.DataFrame({"PopTechIndustries_ID":[i for i in range(16)],"Popular Industry":pop_field2})
print(pop_field_3.head())
# Out:
#   TechHub_Name Popular Industry  Number
# 0       Austin        eCommerce       1
# 1       Austin         Software       2
# 2       Austin            Cloud       3
# 3       Boston           Edtech       1
# 4       Boston         Hardware       2
#    PopTechIndustries_ID Popular Industry
# 0                     0        eCommerce
# 1                     1         Software
# 2                     2            Cloud
# 3                     3           Edtech
# 4                     4         Hardware

# %%
z = df3.merge(pop_field_3, on = "Popular Industry")
z=z[["TechHub_Name", "Number", "PopTechIndustries_ID"]]
z["Number"]=z["Number"].astype(int)

# %%
z.dtypes
# Out:
# TechHub_Name            object
# Number                   int32
# PopTechIndustries_ID     int64
# dtype: object

# %%
final = z.pivot(index = "TechHub_Name",columns="Number", values = "PopTechIndustries_ID")

final
# Out:
# Number            1     2     3
# TechHub_Name
# Austin          0.0   1.0   2.0
# Boston          3.0   4.0   5.0
# Chicago         6.0   7.0   8.0
# Colorado        1.0   9.0  10.0
# Los Angeles    11.0  12.0   0.0
# NYC            13.0   6.0  12.0
# San Francisco   6.0  14.0   NaN
# Seattle         1.0  15.0   7.0

# %%
final_tech = TechHub.merge(final,  on = "TechHub_Name")

# %%
final_tech = final_tech.rename(columns = {1:"Industry_1",2:"Industry_2",3:"Industry_3"})
final_tech.fillna(100, inplace = True)

# %%
final_tech["TechHub_Name"]=final_tech["TechHub_Name"].astype(str)

# %%
final_tech.dtypes
# Out:
# TechHub_Name            object
# Rent_OneBedroom         object
# Lunch_Price             object
# Median_HomePrice        object
# Population              object
# Number_TechCompanies    object
# Industry_1               int32
# Industry_2               int32
# Industry_3               int32
# dtype: object

# %%
#final_tech.to_csv("Tech_Hub2.csv")

# %%
Salary_df.head(10)
# Out:
#   TechHub_Name     Category_Name Avg Salary
# 0       Austin    Dev + Engineer   $125,808
# 1       Austin       Design + UX   $103,075
# 2       Austin           Product   $126,508
# 3       Austin         Marketing    $96,128
# 4       Austin           Finance   $109,455
# 5       Austin             Sales    $80,982
# 6       Austin  Data + Analytics   $106,893
# 0       Boston    Dev + Engineer   $127,741
# 1       Boston       Design + UX   $111,524
# 2       Boston           Product   $138,685

# %%
Categories = pd.DataFrame({"Category_Name": ["Dev + Engineer","Design + UX","Product","Marketing","Finance","Sales","Data + Analytics"]})
Categories.to_csv("Category.csv")

# %%
Categories["JobCategory_ID"]=[0,1,2,3,4,5,6]

# %%
Categories
# Out:
#       Category_Name  JobCategory_ID
# 0    Dev + Engineer               0
# 1       Design + UX               1
# 2           Product               2
# 3         Marketing               3
# 4           Finance               4
# 5             Sales               5
# 6  Data + Analytics               6

# %%
final_tech.dtypes
# Out:
# TechHub_Name             object
# Rent_OneBedroom          object
# Lunch_Price              object
# Median_HomePrice         object
# Population               object
# Number_TechCompanies     object
# Industry_1              float64
# Industry_2              float64
# Industry_3              float64
# dtype: object

# %%
th = pd.read_csv("Tech_Hub2.csv")
th2=th[["Unnamed: 0","TechHub_Name"]]
th3 = th2.rename(columns = {"Unnamed: 0":"TechHub_ID"})
th3
# Out:
#    TechHub_ID   TechHub_Name
# 0           0         Austin
# 1           1         Boston
# 2           2        Chicago
# 3           3       Colorado
# 4           4    Los Angeles
# 5           5            NYC
# 6           6  San Francisco
# 7           7        Seattle

# %%
ws = Salary_df.merge(th3, on = "TechHub_Name")
ws2 = ws.merge(Categories, on = "Category_Name")
salaryfinal = ws2[["TechHub_ID","JobCategory_ID","Avg Salary"]]
salaryfinal.to_csv("salary.csv")
